# %%
import os
import cv2
from utils.show import *

# %%
from utils.weatheraug import *

# %%
os.listdir('../data')
# Out:
# ['4.png', '5.png', '2.png', '3.png', '1.png', '0.png']

# %%
img = cv2.imread('../data/3.png')

# %%
show(img, add_brightness(img))

# %%
show(img, add_shadow(img))

# %%
show(img, add_snow(img))

# %%
show(img, add_rain(img))

# %%
show(img, add_fog(img))
# Out:
# (491, 310) 100
# (521, 114) 100
# (523, 106) 100
# (354, 305) 100
# (435, 300) 100
# (336, 280) 100
# (531, 88) 100
# (316, 235) 100
# (331, 198) 100
# (376, 74) 100
# (317, 274) 100
# (282, 116) 100
# (319, 219) 100
# (562, 326) 100
# (429, 117) 100
# (544, 369) 100
# (283, 251) 100
# (381, 90) 100
# (408, 190) 100
# (303, 135) 100
# (458, 228) 100
# (425, 251) 100
# (427, 245) 100
# (354, 363) 100
# (451, 209) 100
# (543, 249) 100
# (351, 218) 100
# (530, 340) 100
# (444, 367) 100
# (328, 94) 100
# (537, 273) 100
# (417, 360) 100
# (552, 283) 100
# (381, 159) 100
# (325, 108) 100
# (514, 315) 100
# (341, 188) 100
# (363, 165) 100
# (459, 240) 100
# (560, 102) 100
# (472, 181) 100
# (435, 78) 100
# (527, 226) 100
# (370, 131) 100
# (320, 176) 100
# (305, 134) 100
# (336, 302) 100
# (515, 133) 100
# (531, 214) 100
# (547, 188) 100
# (383, 74) 100
# (399, 166) 100
# (411, 191) 100
# (387, 294) 100
# (568, 151) 100
# (360, 230) 100
# (576, 144) 100
# (350, 347) 100
# (569, 221) 100
# ...
